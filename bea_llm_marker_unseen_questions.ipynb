# %% [markdown]
# Ask an LLM to mark the 3-way task, optionally based on training data or ILP prediction.

# %%
# Only run this cell if you haven't installed the requirements yet:
# %pip install -r requirements-llm.txt
# Out:
# Requirement already satisfied: mistralai in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 1)) (2.0.4)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 2)) (1.2.2)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 3)) (3.0.1)
# Requirement already satisfied: ujson in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 4)) (5.12.0)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 5)) (1.8.0)
# Requirement already satisfied: tiktoken in ./.venv/lib/python3.13/site-packages (from -r requirements-llm.txt (line 6)) (0.12.0)
# Requirement already satisfied: eval-type-backport>=0.2.0 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (0.3.1)
# Requirement already satisfied: httpx>=0.28.1 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (0.28.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.33.1 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions<0.61,>=0.60b1 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (0.60b1)
# Requirement already satisfied: pydantic>=2.11.2 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (2.12.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.13/site-packages (from mistralai->-r requirements-llm.txt (line 1)) (0.4.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in ./.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.33.1->mistralai->-r requirements-llm.txt (line 1)) (8.7.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.33.1->mistralai->-r requirements-llm.txt (line 1)) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.33.1->mistralai->-r requirements-llm.txt (line 1)) (3.23.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pandas->-r requirements-llm.txt (line 3)) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->-r requirements-llm.txt (line 5)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->-r requirements-llm.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in ./.venv/lib/python3.13/site-packages (from scikit-learn->-r requirements-llm.txt (line 5)) (3.6.0)
# Requirement already satisfied: regex>=2022.1.18 in ./.venv/lib/python3.13/site-packages (from tiktoken->-r requirements-llm.txt (line 6)) (2026.2.28)
# Requirement already satisfied: requests>=2.26.0 in ./.venv/lib/python3.13/site-packages (from tiktoken->-r requirements-llm.txt (line 6)) (2.32.5)
# Requirement already satisfied: anyio in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->mistralai->-r requirements-llm.txt (line 1)) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->mistralai->-r requirements-llm.txt (line 1)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->mistralai->-r requirements-llm.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.13/site-packages (from httpx>=0.28.1->mistralai->-r requirements-llm.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.28.1->mistralai->-r requirements-llm.txt (line 1)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.11.2->mistralai->-r requirements-llm.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.11.2->mistralai->-r requirements-llm.txt (line 1)) (2.41.5)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->mistralai->-r requirements-llm.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->-r requirements-llm.txt (line 6)) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.13/site-packages (from requests>=2.26.0->tiktoken->-r requirements-llm.txt (line 6)) (2.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
tasks = ["2-way", "3-way"] 
tracks = ["unseen_questions"]#,"unseen_answers" ]
# "gold" and "ilponly" cases generated elsewhere from *_TASK_with_prediction.json
#cases = ["trained", "with_ilp", "with_theory", "with_test_ilp", "with_ilp_and_theory", "with_test_ilp_and_theory"] #
cases = ["trained", "with_theory"]#, "with_test_ilp", "with_test_ilp_and_theory"] 


################################################################################
# These are the main parameters to set for the experiment. Adjust as needed.   #
# What are we doing?                                                           #
################################################################################
#track = tracks[0]
#task = tasks[0]
#case = cases[0]

# %%
schema = {
    "3-way": {
        "type": "object",
        "additionalProperties": False,
        "required": ["id", "question_id", "score"],
        "properties": {
            "id": {
                "type": "string"
            },
            "question_id": {
                "type": "string"
            },
            "score": {
                "enum": ["Incorrect", "Partially correct", "Correct"]
            },
            "explanation": {
                "type": "string"
            }
        }
    },
    "2-way": {
        "type": "object",
        "additionalProperties": False,
        "required": ["id", "question_id", "score"],
        "properties": {
            "id": {
                "type": "string"
            },
            "question_id": {
                "type": "string"
            },
            "score": {
                "enum": ["Incorrect", "Correct"]
            },
            "explanation": {
                "type": "string"
            }
        }
    }
}

# %%
import pandas as pd
import ujson

from dotenv import load_dotenv
load_dotenv()

import os

cwd = os.getcwd()
print(f"Current working directory: {cwd}")

from mistralai.client import Mistral

import random

import tiktoken
tokenizer = tiktoken.get_encoding("cl100k_base")

client = Mistral(api_key=os.getenv("MISTRALAI_API_KEY"))
# Out:
# Current working directory: /Users/at6737/Work/Projects/AI & Assessment/BEA 2026/bea-2026

# %%
# OneMassiveFunctionTM because this is how smart people do it, right?
# Copilot wrote all of the next comment:
#  Right?? (Also, I want to be able to easily run different cases without having to copy-paste a bunch of code, and I don't want to have to worry about variable scope issues with global variables, so here we are.)
def run_experiment(task, track, case):
    # Include ILP theory in the prompt 
    if "theory" in case:
        include_theory=True
    else:
        include_theory=False
    # Whether to include ILP results for the test question in the prompt (only relevant if arm == "with_ilp")
    if "test_ilp" in case:
        with_test_ilp = True
    else:
        with_test_ilp = False

    #inputfile = os.path.join(f"{task}", f"trial_{task.replace('-', '')}_with_prediction.json")
    inputfile = os.path.join(f"BEA_full_challenge_attempt/{task}-test", f"{task.replace('-', '')}_{track}_eval.json")
    trainingfile = os.path.join(f"{task}", f"train_{task.replace('-', '')}_with_prediction.json")
    theoryfile = os.path.join(f"{task}", f"{task}_theories.json")
    promptprefix = f"{task}_trained" if not "ilp" in case else f"{task}_with_ilp"
    promptfile = os.path.join(f"{task}", "prompts", f"{promptprefix}.txt")
    theoryprompt = os.path.join(f"{task}", "prompts", f"theory_prompt_fragment.txt")
    responsesprefix = f"{task}_{case}_responses"
    responsesfile = os.path.join(".", "results-real", f"{track}_{responsesprefix}.json")


    # Read in prompts
    with open(promptfile, "r") as f:
        prompt = f.read()

    splitprompt = prompt.split("#####")
    systemprompt = splitprompt[0].replace("${task}", str(schema[task]))
    prompt = splitprompt[1]

    if include_theory:
        with open(theoryprompt, "r") as f:
            theory_fragment = f.read()
        systemprompt += "\n\n" + theory_fragment

    # Read in training data
    with open(trainingfile, "r") as f:
        training_data = ujson.load(f)
    # Read in input data
    with open(inputfile, "r") as f:
        input_data = ujson.load(f)

    count = 0
    responses = []
    #batch_requests = []
    # Process each input item in turn
    for current in input_data:
        # Limit results for debugging
        # if count > 5:
        #    break
        count += 1
        current_training_data = []
        training_data_series = pd.Series(training_data)
        training_data = training_data_series.sample(n=112, random_state=33)
        for item in training_data:
            current_training_data.append(item)
        current_system_prompt = systemprompt.replace(
            "${training}", str(current_training_data))
        if include_theory:
            with open(theoryfile, "r") as f:
                theory_data = ujson.load(f)
            current_system_prompt = current_system_prompt.replace("${theory}", str(
                theory_data.get(current["question_id"], "No theory available")))
        current.pop("score", None)
        if "with_ilp" in case and not with_test_ilp:
            current.pop("amati", None)
        current_prompt = prompt.replace("${data}", str(current))
        print(f"Current: {count}/{len(input_data)}")
        # full_current_prompt_tokenized = tokenizer.encode(current_system_prompt+current_prompt)
        # print(len(full_current_prompt_tokenized))

        response = client.chat.complete(
            model="mistral-large-latest",
            messages=[
                {
                    "role": "system",
                    "content": current_system_prompt
                },
                {
                    "role": "user",
                    "content": current_prompt
                }
            ],
            response_format={
                "type": "json_schema",
                "json_schema": {
                    "name": "bea",
                    "strict": True,
                    "schema_definition": schema[task]
                }
            }
        )
        #batch_request = {
        #    "custom_id": f"{case}_{count}",
        #    "body": {
        #        "messages": messages,
        #        "response_format": response_format
        #    }
        #}
        #batch_requests.append(batch_request)

    #with open(os.path.join("results", f"batch-{task}-{case}.jsonl"), "w") as f:
    #    for request in batch_requests:
    #        f.write(ujson.dumps(request) + "\n")

        responses.append(response.choices[0].message.content)
        #print(response.choices[0].message.content)

    properresponses = []
    for entry in responses:
        properresponses.append(ujson.loads(entry))
    with open(responsesfile, "w") as f:
        f.write("{\n")
        f.write(f"    \"task\": \"{task}\",\
        \"case\": \"{case}\",\
        \"track\": \"{track}\",\
        \"results\": ")
        ujson.dump(properresponses, f)
        f.write("}")

# %%
for track in tracks:
    for task in tasks:
        for case in cases:
            run_experiment(task, track, case)
# Out:
# {'id': '446892a2-201d-4482-bd15-73374604dacd', 'question_id': 'a400cdc0-ed2f-4adf-928d-816320717a92', 'question': 'Erläutere...\n(a) wie dieser Mitschüler zu dieser falschen Aussage gelangen könnte.\n(b) wie Du ihn davon überzeugen würdest, dass diese Aussage nicht korrekt ist (z.B. mit welchen Versuchsdaten).', 'answer': 'Masse mit der Waage .\nVolumen mit Messbecher .\nKonzentration mit Messgerät oder indem Mann das Wasser abkocht und dann das Verhältnis des Wassers mit den Stoffen misst .\n', 'rubric': {'Incorrect': ['Die Schüler:innen erläutern weder das Zustandekommen möglicher Fehlinterpretationen, noch beziehen sie die Daten mit ein.', 'Die Schüler:innen erläutern das Zustandekommen möglicher Fehlinterpretationen mit der Annahme gleicher Entitäten, ohne jedoch konkrete Daten mit einzubeziehen.'], 'Correct': 'Die Schüler:innen erläutern das Zustandekommen möglicher Fehlinterpretationen mit der Annahme gleicher Entitäten und beziehen konkrete Daten mit ein.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"wasser"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"stoff"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'incorrect'}}
# {'id': '1e8f2ce1-0def-4e1c-b5f2-2ae9d62cd547', 'question_id': 'cb99dfb3-2788-4a10-b934-7ea8276b2b44', 'question': 'Beschreibe auf Basis Deines Vorwissens die Erklärungskraft der submikroskopischen Ebene (was vermag diese Modellebene darzustellen?).', 'answer': 'Die Veränderung der Moleküle in ihrer Form und Struktur\n', 'rubric': {'Incorrect': ['Die Schüler:innen erläutern den erweiterten Blick der makroskopischen Ebene nicht.', 'Die Schüler:innen erläuten den Vorteil, dass die submikroskopische Ebene mit dem Teilchenbegriff die makroskopischen Blick erweitert.'], 'Correct': 'Die Schüler:innen erläutern den Vorteil, dass mithilfe von Teilchen und deren Interaktionen Phänomene erklärt werden können.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"form"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '7783798c-4479-433c-9974-223c84160102', 'question_id': '8e686080-6db7-473b-baa0-6f17412fae5c', 'question': 'Beschreibe anhand welcher makroskopischen Beobachtung du eine Veränderung der momentanen Reaktionsgeschwindigkeit beobachten kannst.', 'answer': 'Dadurch dass die Gasbildung zu Anfang und zum Ende schwächer ist , sieht man dass die Reaktionsgeschwindigkeit langsamer ist an diesen Stellen\n', 'rubric': {'Incorrect': ['Die Schüler:innen beschreiben das Phänomen wiederholend ohne Bezug zur momentanen Reaktionsgeschwindigkeit.', 'Die Schüler:innen beschreiben die Gasentwicklung als entscheidende Beobachtung.'], 'Correct': 'Die Schüler:innen beschreiben die Gasentwicklung als entscheidende Beobachtung und verknüpfen sie mit der Stoffgröße Volumen als Funktion der Zeit.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"reaktionsgeschwindigkeit"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '826c5315-7558-4fb9-9f4a-64f389a04ad5', 'question_id': '4ca6cd4c-9b4a-4226-89ec-14a4d8621968', 'question': 'Beschreibe zunächst die Kurvenverläufe.', 'answer': 'Die Kurven haben ihren Ursprung alle bei 0. Sie steigen im Bereich von 100 Sekunden jedoch verschieden schnell an , weshalb sie nicht übereinander liegen .\nIm hinteren Bereich des Graphen also ab 100 flachen die Kurven ab und sind fast parallel zur x-Achse .\n', 'rubric': {'Incorrect': ['Die Schüler:innen beschreiben die vorliegenden Daten nicht.', 'Die Schüler:innen beschreiben die Kurvenverläufe auf Basis von Oberflächenmerkmalen (z. B. Anstieg).'], 'Correct': 'Die Schüler:innen beschreiben die Kurvenverläufe auf Basis von Oberflächenmerkmalen und nennen relevante Werte.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"kurve"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"100"', 'id': '@2'}], 'prediction': 'correct'}}
# {'id': 'f20e5d79-79c4-43c0-947e-a5bef5c1d6f9', 'question_id': '52f6e329-eea6-423b-8d6a-047448d02c3f', 'question': 'Beschreibe die Veränderung der Reaktionsraten zu den in der Aktivität gewählten Zeitpunkten in der folgenden Tabelle.', 'answer': 'Reaktionsraten im Verlauf Reaktionsrate Zu Beginn der Veresterung Nach kurzer Reaktionszeit Im Gleichgewichtszustand Hinreaktion sehr hohe Reaktionsrate hoch mittel Rückreaktion sehr niedrig niedrig mittel\n', 'rubric': {'Incorrect': ['Die Schüler:innen analysieren die Veränderung der Reaktionsraten nicht.', 'Die Schüler:innen analysieren die Reaktionsraten im zeitlichen Verlauf zu wenigstens zwei Zeitpunkten in angemessener Weise.'], 'Correct': 'Die Schüler:innen analysieren die Reaktionsraten im zeitlichen Verlauf vollständig und in angemessener Weise.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"hoch"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"rückreaktion"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': 'da7b09d2-ef30-41e1-88f7-abace79b319c', 'question_id': '278f349f-1552-41c4-bec2-1de41838f229', 'question': 'Beschreibe die oben dargstellten Phänomene in eigenen Worten und charaktersiere diese als chemische Reaktion.', 'answer': 'In Abbildung 1 ist der Darm erkennbar und wie ein Brötchen verdaut wird .\nWeizenmehl wird in seine Grundbausteine unteranderem Stärke und Kohlenhydrate abgebaut durch Enzymaktivitäten .\nDie frei werdende Energie dient zum einen der Muskulatur und der Herstellung von ATP .\nDabei kann das Protein Gluten von einigen MEnschen nicht abgebaut und bilden Antikörper .\nIn Abbildung 2 ist ein Hefeteig erkennbar .\nDie Hefe reagiert mit Wasser zusammen und geht in eine feste Masse auf .\nMoleküle dehnen sich aus .\nIn Abbildung 3 wird eine Verbrennunsreaktion von Weizenmehl mit einer Bunsenbrennerflamme dargestellt .\nDurch pusten wird Mehl in die Flamme geschleuder .\nEs wird viel Energie frei weil Kohlenstoffdioxid mit Sauerstoff reagiert .\n', 'rubric': {'Incorrect': ['Die Schüler:innen beschreiben weder die Reaktionsbespiele noch beziehen sie zentrale Kennzeichen chemischer Reaktionen mit ein', 'Die Schüler:innen beschreiben den Ablauf der Reaktionsbeispiele und beziehen ein Kennzeichen chemischer Reaktionen mit ein'], 'Correct': 'Die Schüler:innen beschreiben den Ablauf der Reaktionsbeispiele beider zentraler Kennzeichen chemischer Reaktionen'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"energie"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"hefe"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': 'cf4bcf7b-ec5b-4df4-a5a9-94fd91d44f36', 'question_id': '1f2f0773-54bb-4b72-963e-c3c946a1f53f', 'question': 'Erkläre, in eigenen Worten, warum du dich für diese Lampe entschieden hast.', 'answer': 'Ich habe mich für die Energiesparlampe entschieden , da diese Energie spart und ein schönes Licht macht .\n', 'rubric': {'Incorrect': ['Die SuS formulieren keine Begründung für ihre Wahl.', 'Die SuS formulieren eine Begründung basierend auf physikalischen Prinzipien oder gesellschaftlichen/ ökologischen Beweggründen.'], 'Correct': 'Die SuS formulieren eine Begründung basierend auf physikalischen Prinzipien und gesellschaftlichen/ ökologischen Beweggründen.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"energie"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"energiesparlampe"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': 'c444d242-0c93-4dad-ae5c-76823c8d8bd4', 'question_id': '40c10a59-eeab-4673-b943-69e501cfef5f', 'question': 'Formuliere auf Basis Deiner qualitativen Beobachtungsdaten und Deiner Sizze eine allgemeine Gesetzmäßigkeit zum Einfluss des Zerteilungsgrades auf die Reaktionsgeschwindigkeit.', 'answer': 'Je höher der Zerteilungsgrad desto höher ist die Reaktionsgeschwindigkeit .\n', 'rubric': {'Incorrect': ['Die Schüler:innen formulieren keine korrekte allgemeine Gesetzmäßigkeit.', 'Die Schüler:innen formulieren eine allgemeine Gesetzmäßigkeit zur positiven Korrelation des Zerteilungsgrad und der Reaktionsgeschwindigkeit, ohne hierbei das erzeugte V,t-Diagramm einzubeziehen.'], 'Correct': 'Die Schüler;innen formulieren eine allgemeine Gesetzmäßigkeit zur positiven Korrelation des Zerteilungsgrad und der Reaktionsgeschwindigkeit und beziehen hierbei das erzeugte V,t-Diagramm mit ein.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"zerteilungsgrad"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '6e14206b-b4b9-4794-8b8f-b028090c41c9', 'question_id': '64636904-aab6-4e10-a4dc-39638117731a', 'question': 'Erkläre kurz, warum du dich für wahr oder falsch entschieden hast.', 'answer': 'Ich habe mich für wahr entschieden , weil es richtig ist\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die Steigung des Graphen als Geschwindigkeit noch schließen sie daraus, dass die höhere Laufgeschwindigkeiten einen steileren Anstieg haben.', 'Die SuS beschreiben entweder die Steigung des Graphen als Geschwindigkeit oder sie stellen fest, dass eine höhere Laufgeschwindigkeit einen steileren Anstieg bedeutet.'], 'Correct': 'Die SuS beschreiben die Steigung des Graphen als Geschwindigkeit und stellen fest, dass bei höherer Geschwindigkeit der Anstieg steiler wird.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"entscheiden"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'a2b73959-433f-4572-aead-da759c9d5324', 'question_id': 'b1a78d64-0171-4180-b564-1172fbb92608', 'question': 'Begründe Deine Auswahl!', 'answer': 'Ich glaube , da man an der Reaktionsgleichung erkennen kann dass wir am Ende kein Oxonium Ion mehr haben , dass die Konzentration daher abnimmt .\nDieser Verlauf erklärt dass mitzunehmer Reaktion , die Konzentration immer weniger wird , dass aber ab einem gewissen Zeitpunkt sich die Konzentration nicht mehr verändert .\n', 'rubric': {'Incorrect': ['Die Schüler:innen stellen keine Annahmen zur zeitlichen Veränderung der benannten Stoffgrößen auf.', 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Abnahme), charaktersieren diese allerdings als linear.'], 'Correct': 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Abnahme) und charaktersieren diese als Abklingfunktion.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"reaktionsgleichung"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '8b1e4a60-3768-4d7d-ac49-998b389e2522', 'question_id': '3d62bda8-dc02-47aa-ae1e-dc0f5e2aef1b', 'question': 'Begründe deine Auswahl!', 'answer': 'Der Wasserstoff wird gleichmäßig während der Reaktion abgegeben\n', 'rubric': {'Incorrect': ['Die Schüler:innen stellen keine Annahmen zur zeitlichen Veränderung der benannten Stoffgrößen auf.', 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Zunahme), charaktersieren diese allerdings als linear.'], 'Correct': 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Zunahme) und charaktersieren diese als Sättigungsfunktion.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"gleichmäßig"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'f729633f-04cd-45ac-a847-e83fd152f4a4', 'question_id': '82aacab8-0c7f-4936-b93f-62c53670b5c3', 'question': 'Benenne Konsequenzen, die die Gasknappheit für Deutschland und deine Schule bedeuten könnte.', 'answer': 'Kalte Räume Wenig Geld wegen der hohen Preise Kein Benzin Holz wird knapp durchs heizen von Öfen\n', 'rubric': {'Incorrect': ['Die SuS stellen keinen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.', 'Die SuS stellen einen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'], 'Correct': 'Die SuS stellen mindestens zwei Zusammenhänge zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"kalt"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': '76dfe426-da26-4e43-8879-821773b222c2', 'question_id': 'dddf3a9d-2f40-402c-b650-3db1b27128ca', 'question': 'Formuliere eine Planung und Strategie für die 17. Etappe der Tour de France für den Teamchef eures Radrennteams. Beurteile die Planung und Strategie durch die mathematischen Ergebnisse.', 'answer': 'Man sollte die Kräfte sparen , wo die Steigung 1 % ist .\nDamit man genug Kraft für die letzten Abschnitte der Etappe hat .\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder den Verlauf der Anstiege im Streckenverlauf noch schließen sie daraus, dass zu Beginn der Etappe Kräfte gespart werden sollten.', 'Die SuS beschreiben entweder den Verlauf der Anstiege im Streckenverlauf oder sie stellen fest, dass zu Beginn der Etappe Kräfte gespart werden sollten.'], 'Correct': 'Die SuS beschreiben den Verlauf der Anstiege im Streckenverlauf und stellen fest, dass zu Beginn der Etappe Kräfte gespart werden sollten.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"abschnitt"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '6da7a9de-01b2-4981-be27-dfb271c9a806', 'question_id': '1ed16c88-ff9d-488c-be13-6ba2be1d1cc0', 'question': 'Leitet auf Grundlage der Muster und der Messwerte zwei "Je - desto" Aussagen für die Ausrichtung der PV-Zelle ab.', 'answer': 'Haben wir schon gemacht .\n', 'rubric': {'Incorrect': ['Die SuS formulieren keine je-desto-Aussagen zum Einstrahlungswinkel und beschienenen Fläche.', 'Die SuS formulieren eine je-desto-Aussagen zu Einstrahlungswinkel oder beschienenen Fläche.'], 'Correct': 'Die SuS formulieren zwei je-desto-Aussagen zu Einstrahlungswinkel und beschienenen Fläche.'}, 'score': 'Incorrect', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': 'ce786f58-30fc-434a-bc25-00e1f2fcf1b3', 'question_id': '48071573-9e44-4ae9-b08c-2b19b6ee58d6', 'question': 'Erkläre abschließend, wie sich eine Gleichgewichtskonstante von K = 4,12 bei der von uns betrachteten Aromasynthese interpretieren lässt.', 'answer': 'Wenn die gleichgewichtskonstante K = 4,12 beträgt bedeutet es , dass die Hinreaktion favorisiert wird und somit die Bildung der Produkte .\nDer Wert von 4,12 gibt außerdem noch an , dass die beiden Graphen , bzw. die konzentration der Pro-und Edukte sich stark voneinander unterscheiden\n', 'rubric': {'Incorrect': ['Die Schüler:innen fassen keine Erkenntnisse zur Gleichgewichtskonstante zusammen.', 'Die Schüler:innen interpretieren die Gleichgewichtskonstante mit Bezug auf Priorisierung einer der Reaktionen, ziehen aber die falsche Schlussfolgerung.'], 'Correct': 'Die Schüler:innen interpretieren die Gleichgewichtskonstante mit Bezug auf Priorisierung einer der Reaktionen und ziehen  die richtige Schlussfolgerung.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"hinreaktion"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': '330915d5-c51e-4324-943f-f8f2ccb7af81', 'question_id': '1ed16c88-ff9d-488c-be13-6ba2be1d1cc0', 'question': 'Leitet auf Grundlage der Muster und der Messwerte zwei "Je - desto" Aussagen für die Ausrichtung der PV-Zelle ab.', 'answer': 'Je , näher der Winkel an den 30 ° ist und insgesamt mit dem Lod verbunden , desto mehr kann die Solarzelle aufnehmen\n', 'rubric': {'Incorrect': ['Die SuS formulieren keine je-desto-Aussagen zum Einstrahlungswinkel und beschienenen Fläche.', 'Die SuS formulieren eine je-desto-Aussagen zu Einstrahlungswinkel oder beschienenen Fläche.'], 'Correct': 'Die SuS formulieren zwei je-desto-Aussagen zu Einstrahlungswinkel und beschienenen Fläche.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"30"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '5328dcc7-1978-43b4-8290-b9c1d0b495e3', 'question_id': '1e0b7fa1-1947-40eb-9ffa-b2a46853da49', 'question': 'Hast Du auf Grundlage der oben beantworteten Aufgaben bereits Ideen, welche Größen geeignet sein könnten, um die Geschwindigkeit dieser Reaktion zu erfassen? Wenn ja, beschreibe und begründe Deine Ideen', 'answer': 'Die Reaktionsgeschwindigkeit könnte mithilfe der Effizienz von Katalysatoren gemessen werden .\nSomit wäre auch die Konzentration eines Katalysatoren eine gute Maßeinheit für die Reaktionsgeschwindigkeit .\nDies lässt sich anhand der Verwendung von dem Enzym Amylase begründen , welcher den Stoffwechselvorgang begünstigt .\nAuch gute Außenbedingungen wie beispielsweise ein wässriges Medium , könnten zu einer erhöhten Reaktionsgeschwindigkeit führen .\n', 'rubric': {'Incorrect': ['Die Schüler:innen betrachten weder die Reaktionsprodukte, noch leiten sie geeignete Stoffgrößen zur Erfassung der zeitlichen Veränderung her.', 'Die Schüler:innen leiten mindestens zwei geeignete Stoffgrößen zur Erfassung der zeitlichen Veränderung her.'], 'Correct': 'Die Schüler:innen leiten mindestens drei geeignete Stoffgrößen zur Erfassung der zeitlichen Veränderung her und stellen einen sinnvollen Zusammenhang her.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"messen"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '61fc16c1-06ac-4c1a-b0c7-4e582e55566d', 'question_id': '379ba896-bb8f-440d-9d32-5dc9ca0297fe', 'question': 'Formuliere selbst eine Fragestellung.', 'answer': 'Frage : sind lineare oder exponentiele funktionen\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die durchschnittliche Geschwindigkeit in Abschnitten, Segmenten etc. noch schließen sie daraus, dass sich damit die Geschwindigkeit bestimmten lässt.', 'Die SuS beschreiben entweder die durchschnittliche Geschwindigkeit ohne Zusammenhang mit einzelnen Segmenten bzw. Abschnitten oder sie stellen fest, dass die Geschwindigkeit in einzelnen Segmenten bzw. Anschnitten betrachtet werden kann ohne Zusammenhang zur durchschnittliche Geschwindigkeit.'], 'Correct': 'Die SuS beschreiben die durchschnittliche Geschwindigkeit und stellen fest, dass einzelne Segmente betrachtet werden können um die Geschwindigkeit in diesem Abschnitten zu bestimmen.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"frage"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'ae9b66c4-75a4-4226-adb2-b641f39f54e7', 'question_id': 'c405c4a8-83f2-4ddf-b0cf-941a3356b251', 'question': 'Beantworte jeweils eine der wissenschaftlichen Fragen aus der ersten Stunde mit einer Erklärung, die auf dem Konzept der\n\n(1) Natürlichen Selektion\n(2) Sexuellen Selektion\n(3) Mutation\n\nberuht. Benutze dazu das CER-Schema!', 'answer': 'C1 : Unterschiedliche Musterungen entsteht durch natürliche Selektion .\nEvidence : Die Guppys die am besten an ihren Lebensraum angepasst sind mit der Musterung / Färbung überleben .\nReasoning : Dadurch das die Guppys nur überleben wenn sie an ihren lebensraum angepasst sind ist die unterschiedliche musterung entstanden .\n', 'rubric': {'Incorrect': ['Die Erklärung \n... beschreibt das Vorhandensein  phänotypischer Variation \nund/oder \n... das Auftreten verschiedener Merkmalsfrequenzen ohne weitere (korrekte) Erklärung.', 'Die Erklärung ...\n... beschreibt das Vorhandensein phänotypischer Variation\nund\n... das Auftreten  verschiedener Merkmalsfrequenzen \nund \n... beschreibt ein oder zwei der Konzepte [UNTERSCH. ÜBERLEBENSCHANCEN, UNTERSCH. FORTPFLANZUNGSERFOLG, VERERBUNG, VERÄNDERTE ALLELFREQUENZ, VERÄNDERTE MERKMALSFREQUENZ].'], 'Correct': 'Die Erklärung ...\n... beschreibt das Vorhandensein phänotypischer Variation\nund\n... das Auftreten  verschiedener Merkmalsfrequenzen \nund \n... beschreibt drei bis fünf der Konzepte [UNTERSCH. ÜBERLEBENSCHANCEN, UNTERSCH. FORTPFLANZUNGSERFOLG, VERERBUNG, VERÄNDERTE ALLELFREQUENZ, VERÄNDERTE MERKMALSFREQUENZ].'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"selektion"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '8eea759f-d7e4-4a96-8242-8665b4516012', 'question_id': 'b470d591-dc0c-41e1-afa7-4f212d6248e5', 'question': 'Beschreibe die geschwindigkeitsbezogene Häufigkeitsverteilung von Teilchen bei einer Temperatur von 22 °C.', 'answer': 'Beantwortung der Impulsfrage Mögliche Darstellung in einer Animation des Kollisionsmodell prozentualer Anteil an Teilchen sehr hoch , Geschwindigkeit niedrig viele Teilchen darstellen , bewegen sich langsam im Raum umher\n', 'rubric': {'Incorrect': ['Die MB-Verteilung wird weder aufgabenbezogen korrekt gedeutet noch deren Deutung auf das submikroskopische Modell übertragen.', 'Die MB-Verteilung wird aufgabenbezogen korrekt gedeutet, aber die Deutung wird nicht  auf das submikroskopische Modell übertragen.'], 'Correct': 'Die MB-Verteilung wird aufgabenbezogen korrekt gedeutet und die Deutung wird korrekt auf das submikroskopische Modell übertragen.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"möglich"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '50926cdf-4c12-4061-bcec-716f2ab6d160', 'question_id': '8144573c-97d6-484a-b68b-c16b7602fa7b', 'question': 'Welche Dir bereits bekannte Größe liefert die Steigung der jeweilgen Gerade/Tangenten also unmittelbar (beachte die Einheit)?', 'answer': 'die Reaktionsgeschwindigkeit der H3O + Teilchen damit ebenfalls dargestellt\n', 'rubric': {'Incorrect': ['Die Schüler:innen deuten die Einheit weder als Stoffumsatz pro Zeit noch daraufaufbauen als Reaktionsgeschwindigkeit.', 'Die Schüler:innen deuten die Einheit als zeitlich bedingte Änderung der betrachteten Größe oder benennen diese als Reaktionsgeschwindigkeit.'], 'Correct': 'Die Schüler:innen deuten die Einheit als zeitlich bedingte Änderung der betrachteten Größe und benennen diese weiterführend als Reaktionsgeschwindigkeit.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"teilchen"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'a608dbec-a303-4efa-9be6-c6d2af488b11', 'question_id': 'dddf3a9d-2f40-402c-b650-3db1b27128ca', 'question': 'Formuliere eine Planung und Strategie für die 17. Etappe der Tour de France für den Teamchef eures Radrennteams. Beurteile die Planung und Strategie durch die mathematischen Ergebnisse.', 'answer': 'Kräfte gut einteilen , da die späteren Strecken eine höhere Steigung haben und somit schwieriger sind .\nAm Anfang soll ein gutes , aber nicht zu schnelles Tempo gefahren werden , so dass man die weiteren Strecken noch schafft .\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder den Verlauf der Anstiege im Streckenverlauf noch schließen sie daraus, dass zu Beginn der Etappe Kräfte gespart werden sollten.', 'Die SuS beschreiben entweder den Verlauf der Anstiege im Streckenverlauf oder sie stellen fest, dass zu Beginn der Etappe Kräfte gespart werden sollten.'], 'Correct': 'Die SuS beschreiben den Verlauf der Anstiege im Streckenverlauf und stellen fest, dass zu Beginn der Etappe Kräfte gespart werden sollten.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"steigung"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"anfang"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': '72182f2b-5858-4401-b4a7-1a61ee6b0611', 'question_id': 'ea3f9eac-c1d2-4bbc-8271-46786e9ccd20', 'question': 'Erläutere, was mit der Energie geschehen ist, die nicht in elektrische Energie umgewandelt wurde.', 'answer': '- thermische Energie- zum Teil werden die Strahlen reflektiert\n', 'rubric': {'Incorrect': ['Die SuS erkennen nicht, dass nicht die vollständige Energie in elektrische Energie umgewandelt wurde.', 'Die SuS erklären, dass Energie unter anderem in thermische Energie umgewandelt oder als Strahlungsenergie reflektiert wurde.'], 'Correct': 'Die SuS erklären, dass Energie unter anderem in thermische Energie umgewandelt und als Strahlungsenergie reflektiert wurde.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"thermisch"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"reflektieren"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': '27d86503-9ff6-4eb1-8c5d-5bef8e1d5210', 'question_id': '9db508e5-9143-4cc1-a9a5-177237180d0b', 'question': 'Vergleiche die Versorgungsmöglichkeiten und erläutere deine Vorstellung einer optimalen Energieversorgung der Schule.', 'answer': 'Eine optimale Versorgung der Schule wäre eine Energiequelle , die nachhaltig ist , aber dennoch genug Strom produziert und nicht allzu teuer ist .\nIn diesem Fall wäre Photovoltaik eine gute Möglichkeit denke ich , da man am Anfang hohe Anschaffungskosten hat , der Strom danach aber sehr günstig ist und auch am nachhaltigstem von allem .\n', 'rubric': {'Incorrect': ['SuS beschreiben weder verschiedene Versorgungsmöglichkeiten noch geben sie eine begründete, favorisierte Energieversorgung an.', 'SuS beschreiben entweder verschiedene Versorgungsmöglichkeiten oder geben eine begründete, favorisierte Energieversorgung an.'], 'Correct': 'SuS beschreiben verschiedene Versorgungsmöglichkeiten und geben eine begründete, favorisierte Energieversorgung an.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"strom"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': 'cedfd6e6-92a6-4114-aaaa-a7ee22ff356c', 'question_id': '64636904-aab6-4e10-a4dc-39638117731a', 'question': 'Erkläre kurz, warum du dich für wahr oder falsch entschieden hast.', 'answer': 'Ganz einfach , ich rate\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die Steigung des Graphen als Geschwindigkeit noch schließen sie daraus, dass die höhere Laufgeschwindigkeiten einen steileren Anstieg haben.', 'Die SuS beschreiben entweder die Steigung des Graphen als Geschwindigkeit oder sie stellen fest, dass eine höhere Laufgeschwindigkeit einen steileren Anstieg bedeutet.'], 'Correct': 'Die SuS beschreiben die Steigung des Graphen als Geschwindigkeit und stellen fest, dass bei höherer Geschwindigkeit der Anstieg steiler wird.'}, 'score': 'Incorrect', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': '9c59086d-caef-445e-b745-4814b0f30549', 'question_id': '9f29fc63-85b9-4959-bb7e-dd3f169b862d', 'question': 'Protokolliere Deine Beobachtungen.', 'answer': 'Ansatz A B C Beobachtung Bildung von Blässchen , reagiert eher langsamer , milchig trüb Bildung von Blässchen , reagiert etwas stärker die Säure schäumt , Bildung von Blässchen , starke Reaktion\n', 'rubric': {'Incorrect': ['Die Schüler:innen protokollieren keine Beobachtungen, die die Gasentwicklung beschreiben.', 'Die Schüler:innen protokollieren Beobachtungen teilweise, decken hierbei aber keinen vollständigen Vergleich zwischen allen drei Ansätzen ab.'], 'Correct': 'Die Schüler:innen protokollieren die Beobachtungen, die die Gasentwicklung beschreiben, vollständig.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"stark"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': '3a6069b1-e3d6-4de5-8b3b-979e697a1876', 'question_id': '82aacab8-0c7f-4936-b93f-62c53670b5c3', 'question': 'Benenne Konsequenzen, die die Gasknappheit für Deutschland und deine Schule bedeuten könnte.', 'answer': '-Weniger Heizen-Kalt- ( wahrscheinlich ) kaltes Wasser\n', 'rubric': {'Incorrect': ['Die SuS stellen keinen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.', 'Die SuS stellen einen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'], 'Correct': 'Die SuS stellen mindestens zwei Zusammenhänge zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"kalt"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': '31fce1e6-0f59-4408-82d4-9d3055e69317', 'question_id': '278f349f-1552-41c4-bec2-1de41838f229', 'question': 'Beschreibe die oben dargstellten Phänomene in eigenen Worten und charaktersiere diese als chemische Reaktion.', 'answer': 'Phänomen a : ein Magen neben dem Rechts ein Toast ist und links ein Brötchen - &gt; Verdauung : Säure reagiert mit Stärke und wird in Zucker umgewandelt .\nPhänomen b : Teig geht auf - &gt; Hefepilze reagieren mit Stärke und werden zu Gasen - &gt; Teig vergrößert sich .\nPhänomen c : Mehlstaubexplosion - &gt; Energie wird freigesetzt\n', 'rubric': {'Incorrect': ['Die Schüler:innen beschreiben weder die Reaktionsbespiele noch beziehen sie zentrale Kennzeichen chemischer Reaktionen mit ein', 'Die Schüler:innen beschreiben den Ablauf der Reaktionsbeispiele und beziehen ein Kennzeichen chemischer Reaktionen mit ein'], 'Correct': 'Die Schüler:innen beschreiben den Ablauf der Reaktionsbeispiele beider zentraler Kennzeichen chemischer Reaktionen'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"teig"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"energie"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': '5fd07530-f02d-4ada-8172-1f712be3648c', 'question_id': 'd14cc74c-805a-45f7-9ad3-2e9f19395ca0', 'question': 'Welchen evolutiven Prozess verursacht Habitatfragmentierung in Baumbeständen?\nSchreibe eine Erklärung nach dem CER-Schema!', 'answer': 'C : Habitatfragmentierung verursacht einen Gründereffekt im Baumbestand .\nE : Inselbildung erzeugt Unterschiede im jeweiligen Genpool .\nR : Werden Teilpopulation geographisch von einander getrennt , kann es zu Gründereffekten kommen .\n', 'rubric': {'Incorrect': ['Die Erklärung \n... benennt das Auftreten von Gendrift oder einen Gründereffekt ohne weitere (korrekte) Erklärung.', 'Die Erklärung \n... benennt das Auftreten von Gendrift oder einen Gründereffekt\nund \n... begründet dies mit der Isolation von Teilpopulationen\noder\n... beschreibt verringerte Variablität oder veränderte Merkmalsfrequenzen oder veränderte Allelfrequenzen in den Teilpopulationen'], 'Correct': 'Die Erklärung \n... benennt das Auftreten von Gendrift oder einen Gründereffekt\nund \n... begründet dies mit der Isolation von Teilpopulationen\nund\n... beschreibt verringerte Variablität oder veränderte Merkmalsfrequenzen oder veränderte Allelfrequenzen in den Teilpopulationen'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"c"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'f86a0ea1-9eba-4b78-a818-7213ae003c92', 'question_id': 'cfb7ac32-173c-4a66-9ee0-771a20eb93ed', 'question': 'Erkläre den Begriff CO2- Äquivalent kurz in eigenen Worten.', 'answer': 'Äquivalente ( CO₂e ) sind eine Masseinheit zur Vereinheitlichung der Klimawirkung der unterschiedlichen Treibhausgase .\n', 'rubric': {'Incorrect': ['Die SuS erklären den Begriff CO2-Äquvalent nicht.', 'Die SuS erklären den Begriff CO2-Äquvalent entweder als Vereinheitlichung unterschiedlicher Treibhausgase oder die Umrechnung auf die Wirkung von CO2.'], 'Correct': 'Die SuS erklären den Begriff CO2-Äquvalent als Vereinheitlichung unterschiedlicher Treibhausgase und die Umrechnung auf die Wirkung von CO2.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"vereinheitlichung"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"treibhausgase"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'incorrect'}}
# {'id': '769fee60-df1b-4d75-87fd-4fd56e481871', 'question_id': '379ba896-bb8f-440d-9d32-5dc9ca0297fe', 'question': 'Formuliere selbst eine Fragestellung.', 'answer': 'Frage : keine Ahnung\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die durchschnittliche Geschwindigkeit in Abschnitten, Segmenten etc. noch schließen sie daraus, dass sich damit die Geschwindigkeit bestimmten lässt.', 'Die SuS beschreiben entweder die durchschnittliche Geschwindigkeit ohne Zusammenhang mit einzelnen Segmenten bzw. Abschnitten oder sie stellen fest, dass die Geschwindigkeit in einzelnen Segmenten bzw. Anschnitten betrachtet werden kann ohne Zusammenhang zur durchschnittliche Geschwindigkeit.'], 'Correct': 'Die SuS beschreiben die durchschnittliche Geschwindigkeit und stellen fest, dass einzelne Segmente betrachtet werden können um die Geschwindigkeit in diesem Abschnitten zu bestimmen.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"frage"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '044c480a-8ca5-43e8-a237-afa7c723667c', 'question_id': 'f97dc224-8c40-4a1e-be11-d71eeca0c510', 'question': 'Sammle zusammen mit einem Partner äußere Merkmale der Stadttauben und unterscheide diese in Gemeinsamkeiten und Unterschiede zwischen den Individuen. Nutze dazu die vorgegebene Tabelle.\nBeispiele:\n    Alle Tauben haben zwei Augen (Gemeinsamkeit).\n    Eine der Tauben hat einen besonders großen Kopf (Unterschied).', 'answer': 'Merkmale der Stadttauben Unterschiede Gemeinsamkeiten Federmuster Homologe Organe ( grundlegend ) Geschlechtsorgane Phänotp ?\nGenetische Informationen Gangart Geschlechter Nahrung Genetischer Aufbau selbe Art Gleiche ökologische Nische\n', 'rubric': {'Incorrect': ['Jeweils weniger als zwei korrekte und relevante Gemeinsamkeiten oder Unterschiede werden genannt.', 'Mindestens zwei korrekte und relevante Gemeinsamkeiten oder mindestens zwei korrekte Unterschiede werden genannt.'], 'Correct': 'Jeweils mindestens zwei korrekte und relevante Gemeinsamkeiten und Unterschiede werden genannt.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"stadttaube"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': 'e6a5b5d8-6fbc-4ff8-9029-224159e772f5', 'question_id': '64636904-aab6-4e10-a4dc-39638117731a', 'question': 'Erkläre kurz, warum du dich für wahr oder falsch entschieden hast.', 'answer': 'Ich habe mich für .. wahr . entschieden , weil ... ich die Zeit durch den Weg dividieren kann , welche jeweils pro Abschnitt angegeben sind .\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die Steigung des Graphen als Geschwindigkeit noch schließen sie daraus, dass die höhere Laufgeschwindigkeiten einen steileren Anstieg haben.', 'Die SuS beschreiben entweder die Steigung des Graphen als Geschwindigkeit oder sie stellen fest, dass eine höhere Laufgeschwindigkeit einen steileren Anstieg bedeutet.'], 'Correct': 'Die SuS beschreiben die Steigung des Graphen als Geschwindigkeit und stellen fest, dass bei höherer Geschwindigkeit der Anstieg steiler wird.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"entscheiden"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'b00400a5-73ce-49c5-85e0-b296517c7111', 'question_id': '82aacab8-0c7f-4936-b93f-62c53670b5c3', 'question': 'Benenne Konsequenzen, die die Gasknappheit für Deutschland und deine Schule bedeuten könnte.', 'answer': 'Durch die Gasknappheit in Deutschland , könnte es bedeuten , dass man zuhause aber auch z. B. in der Schule nicht mehr viel Heizen kann , sodass man in kalten Räumen sitzt .\nZudem können Geschäfte nicht mehr so lange auf haben , da sie die Kosten sonst nicht stemmen können .\n', 'rubric': {'Incorrect': ['Die SuS stellen keinen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.', 'Die SuS stellen einen Zusammenhang zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'], 'Correct': 'Die SuS stellen mindestens zwei Zusammenhänge zwischen einem Gaslieferstopp und der Versorgung von Strom- und/ oder Wärme her.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"kalt"', 'id': '@1'}], 'prediction': 'correct'}}
# {'id': 'b69159a3-5960-4832-a6c0-47a44b8a1030', 'question_id': '1ed16c88-ff9d-488c-be13-6ba2be1d1cc0', 'question': 'Leitet auf Grundlage der Muster und der Messwerte zwei "Je - desto" Aussagen für die Ausrichtung der PV-Zelle ab.', 'answer': 'Je steiler oder flacher die Platte geneigt ist desto weniger Strom kann diese produzieren\n', 'rubric': {'Incorrect': ['Die SuS formulieren keine je-desto-Aussagen zum Einstrahlungswinkel und beschienenen Fläche.', 'Die SuS formulieren eine je-desto-Aussagen zu Einstrahlungswinkel oder beschienenen Fläche.'], 'Correct': 'Die SuS formulieren zwei je-desto-Aussagen zu Einstrahlungswinkel und beschienenen Fläche.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"steiler"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'fe461a5d-eeda-4d3c-bfc3-c504695ab234', 'question_id': '1f2f0773-54bb-4b72-963e-c3c946a1f53f', 'question': 'Erkläre, in eigenen Worten, warum du dich für diese Lampe entschieden hast.', 'answer': 'Weil , LED weniger Strom verbraucht .\n', 'rubric': {'Incorrect': ['Die SuS formulieren keine Begründung für ihre Wahl.', 'Die SuS formulieren eine Begründung basierend auf physikalischen Prinzipien oder gesellschaftlichen/ ökologischen Beweggründen.'], 'Correct': 'Die SuS formulieren eine Begründung basierend auf physikalischen Prinzipien und gesellschaftlichen/ ökologischen Beweggründen.'}, 'score': 'Incorrect', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': '08c15366-2db0-453d-ba83-fcdc9a628b0c', 'question_id': '379ba896-bb8f-440d-9d32-5dc9ca0297fe', 'question': 'Formuliere selbst eine Fragestellung.', 'answer': 'Frage : Wie hoch ist die durschnittliche Geschwindigkeit ?\n', 'rubric': {'Incorrect': ['Die SuS beschreiben weder die durchschnittliche Geschwindigkeit in Abschnitten, Segmenten etc. noch schließen sie daraus, dass sich damit die Geschwindigkeit bestimmten lässt.', 'Die SuS beschreiben entweder die durchschnittliche Geschwindigkeit ohne Zusammenhang mit einzelnen Segmenten bzw. Abschnitten oder sie stellen fest, dass die Geschwindigkeit in einzelnen Segmenten bzw. Anschnitten betrachtet werden kann ohne Zusammenhang zur durchschnittliche Geschwindigkeit.'], 'Correct': 'Die SuS beschreiben die durchschnittliche Geschwindigkeit und stellen fest, dass einzelne Segmente betrachtet werden können um die Geschwindigkeit in diesem Abschnitten zu bestimmen.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"frage"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': 'bc5a5108-3b71-4f2f-8c99-8bf4124ea1de', 'question_id': 'ea3f9eac-c1d2-4bbc-8271-46786e9ccd20', 'question': 'Erläutere, was mit der Energie geschehen ist, die nicht in elektrische Energie umgewandelt wurde.', 'answer': 'Die wird zurückgestoßen\n', 'rubric': {'Incorrect': ['Die SuS erkennen nicht, dass nicht die vollständige Energie in elektrische Energie umgewandelt wurde.', 'Die SuS erklären, dass Energie unter anderem in thermische Energie umgewandelt oder als Strahlungsenergie reflektiert wurde.'], 'Correct': 'Die SuS erklären, dass Energie unter anderem in thermische Energie umgewandelt und als Strahlungsenergie reflektiert wurde.'}, 'score': 'Incorrect', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': '9bd40243-3a02-4cfe-b3fd-9951d9afc953', 'question_id': '5005b73d-b6bd-499c-8d6f-554785c4e523', 'question': 'Ergänze Deine Begründung in der folgenden Tabelle.', 'answer': 'K Begründung der Zuordnung 0,02 c ( Edukte ) &gt; c ( Produkte ) - &gt; K &lt; 1 - &gt; Die Konzentrationen sind deutlich unterschiedlich - &gt; 0,02 0,40 c ( Edukte ) &gt; c ( Produkte ) - &gt; K &lt; 1 - &gt; Die Konzentrationen liegen recht nah beieinander - &gt; 0,4 2,13 c ( Edukte ) &lt; c ( Produkte ) - &gt; K &gt; 1 - &gt; Die Konzentrationen liegen recht nah beieinander - &gt; 2,13 9,71 c ( Edukte ) &lt; c ( Produkte ) - &gt; K &gt; 1 - &gt; Die Konzentrationen sind deutlich unterschiedlich - &gt; 9,71\n', 'rubric': {'Incorrect': ['Die Schüler:innen nutzen weder das MWG, noch erklären sie die Konzentrationsverhältnisse verschiedener Reaktionsverläufe.', 'Die Schüler:innen erklären die Konzentrationsverhältnisse verschiedener Reaktionsverläufe, ohne das MWG einzubeziehen.'], 'Correct': 'Die Schüler:innen nutzen das MWG, um die Konzentrationsverhältnisse verschiedener Reaktionsverläufe zu erklären und beziehen sich hierbei auf Edukt- und Produktkonzentrationen im Gleichgewicht.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"9,71"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"liegen"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# {'id': '4ca42510-a133-4d79-a675-4353c837d178', 'question_id': 'b1a78d64-0171-4180-b564-1172fbb92608', 'question': 'Begründe Deine Auswahl!', 'answer': 'nimmt an konzentration ab mit der zeit . sie wird weniger sauer\n', 'rubric': {'Incorrect': ['Die Schüler:innen stellen keine Annahmen zur zeitlichen Veränderung der benannten Stoffgrößen auf.', 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Abnahme), charaktersieren diese allerdings als linear.'], 'Correct': 'Die Schüler:innen stellen eine korrekte Annanhme zum generellen Verlauf auf (in diesem Fall Abnahme) und charaktersieren diese als Abklingfunktion.'}, 'score': 'Incorrect', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': '0655f060-903b-49c1-86a2-7cabf904da30', 'question_id': 'b3978794-9681-49bd-bc9b-d05bf8d226d8', 'question': 'Entwickle Hypothesen zur Ursache der Unterschiede zwischen Individuen / Variation innerhalb der Art. Greife dabei auf dein Vorwissen zum Thema Genetik aus der Sekundarstufe I zurück. (LK stellt Frage: "Wie entsteht Variation in einer Population, wenn sich die Allelfrequenzen im Genpool nicht verändern?")', 'answer': 'Ursache für Gemeinsamkeiten der Individuen : Die Individuen müssen unter den gleichen Bedingungen leben und haben sich somit gleich an die Bedingungen angepasst .\nUrsache für Unterschiede zwischen den Individuen : Die einen Individuen kommen aus einem eher wärmeren Gebieten die anderen aus kälteren dadurch können verschiedene Muster der Federn entstanden sein .\nDiese Theorien beruhen auf der Variabilität\n', 'rubric': {'Incorrect': ['Die Schüler:innen\n... nennen keine wissenschaftlich korrekte Hypothese/Vermutung zur Ursache der innerartlichen Variation bei Stadttauben.', 'Die Schüler:innen\n... nennen eine wissenschaftlich korrekte Hypothese/Vermutung zur Ursache der innerartlichen Variation bei Stadttauben mit Bezug auf Rekombination, Crossing-over oder Mutation.'], 'Correct': 'Die Schüler:innen\n... nennen mindestens zwei wissenschaftlich korrekte Hypothesen/Vermutungen zur Ursache der innerartlichen Variation bei Stadttauben mit Bezug auf Rekombination, Crossing-over oder Mutation.'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"gemeinsamkeit"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '6645bd4e-bb7c-4454-892c-8ba4d5a3c057', 'question_id': 'e71649c1-57e4-4cf6-a5fe-c55b8568add3', 'question': 'Beschreibe Auffälligkeiten der dargestellten dynamischen Teilchenbewegungen, die Dir zusätzlich zur Bildung von Produkten aufgefallen sind', 'answer': 'Zufällige Teilchenbewegung , Zusammenstoßen von gleichen und unterschiedlichen Teilen , keine regelmäßige Produktbildung .\n', 'rubric': {'Incorrect': ['Die Schüler:innen beschreiben die dargestellte Ineffektivität der Zusammenstöße nicht.', 'Die Schüler:innen beschreiben die dargstellte Ineffektivität der Zusammenstöße auf Basis von Oberflächenmerkmalen.'], 'Correct': 'Die Schüler:innen beschreiben die dargestellte Ineffektivität der Zusammenstöße anhand der ausbleibenden Stoffumwandlung.'}, 'score': 'Correct', 'amati': {'literals': [], 'prediction': 'incorrect'}}
# {'id': '4ddc54d7-2c33-4278-9c48-27b22a68d3b9', 'question_id': '354d95b7-42b8-4e01-be2e-039149095d2d', 'question': 'Beschreibe den Kurvenverlauf des erzeugten Polygonzugs und vergleiche diesen mit Deinen Annahmen zum Verlauf der zeitlichen Änderung der entsprechenden Größe.', 'answer': 'Die Kurve sinkt exponential .\nAm Anfang sinkt sie langsam , später schneller .\n', 'rubric': {'Incorrect': ['Die Schüler:innen diskutieren weder den Stoffumsatz als Funktion der Zeit, noch beziehen sie die tabellarischen und graphischen Messwerte mit ein.', 'Die Schüler:innen diskutieren den Stoffumsatz als Funktion der Zeit teilweise anhand der tabellarischen und graphischen Messwerte (eher oberflächliche Kurvenbeschreibung unter Einbindung nur eines der KEs).'], 'Correct': 'Die Schüler:innen diskutieren den Stoffumsatz als Funktion der Zeit umfassend anhand der tabellarischen und graphischen Messwerte (detailliert unter Einbindung der KEs).'}, 'score': 'Incorrect', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"kurve"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '76a42ffc-655c-4222-854a-2b9da91f19a8', 'question_id': 'fcf5ff56-5e98-4eb7-8df3-afb0544d9739', 'question': 'Erläutere die Auswirkungen der jahreszeitabhängigen Strahlungsenergie auf die Gewinnung von elektrischer Energie durch Photovoltaik.', 'answer': 'Dadurch das im Winter viel weniger Strahlungsenergie kommtals im Sommer wird man im Winter viel weniger mit Strahlungsenergie versorgt , Was dann eventuell den nötigen Bedarf nicht direkt deckt .\nMan könnte versuchen die Sommer Energie zu Speichern das ist Jedoch nicht möglich .\n', 'rubric': {'Incorrect': ['Die SuS erklären nicht, dass dadurch die Möglichkeit der Umwandlung in elektrische Energie jahreszeitabhängig ist.', 'Die SuS erklären, dass durch die unterschiedlichen Strahlungsenergien im Jahresverlauf die Möglichkeit der Umwandlung in elektrische Energie jahreszeitabhängig ist.'], 'Correct': 'Die SuS erklären, dass durch die unterschiedlichen Strahlungsenergien im Jahresverlauf die Möglichkeit der Umwandlung in elektrische Energie jahreszeitabhängig ist und erklären, dass besonders im Winter wenn Energie zum Heizen und Beleuchten benötigt wird, weniger umgewandelt werden kann.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"strahlungsenergie"', 'id': '@1'}, {'pred': 'contains', 'document': 'student_response', 'lemma': '"energie"', 'id': '@2'}, {'pred': 'precedes', 'order': ['@1', '@2']}], 'prediction': 'correct'}}
# ...
# {'id': '64841406-3fa1-4104-a50c-27d9c1c20bb1', 'question_id': '40c10a59-eeab-4673-b943-69e501cfef5f', 'question': 'Formuliere auf Basis Deiner qualitativen Beobachtungsdaten und Deiner Sizze eine allgemeine Gesetzmäßigkeit zum Einfluss des Zerteilungsgrades auf die Reaktionsgeschwindigkeit.', 'answer': 'Je kleiner der Zerteilungsgrad , desto schneller verläuft die Reaktion .\n', 'rubric': {'Incorrect': ['Die Schüler:innen formulieren keine korrekte allgemeine Gesetzmäßigkeit.', 'Die Schüler:innen formulieren eine allgemeine Gesetzmäßigkeit zur positiven Korrelation des Zerteilungsgrad und der Reaktionsgeschwindigkeit, ohne hierbei das erzeugte V,t-Diagramm einzubeziehen.'], 'Correct': 'Die Schüler;innen formulieren eine allgemeine Gesetzmäßigkeit zur positiven Korrelation des Zerteilungsgrad und der Reaktionsgeschwindigkeit und beziehen hierbei das erzeugte V,t-Diagramm mit ein.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"zerteilungsgrad"', 'id': '@1'}], 'prediction': 'incorrect'}}
# {'id': '6a306ff1-622e-4876-a600-1c14b4f4b346', 'question_id': '49441f3e-1d4b-4b06-9cd3-b6669884c2df', 'question': 'Vergleiche die beiden Ansätze und erläutere in welchem der Reaktionsansätze Du das Einstellen eines ähnlichen Reaktionsverlaufs (bezogen auf Edukt- und Produktkonzentrationen) erwartest (oder nicht erwartest).', 'answer': 'Bei A handelt es sich um ein offenes System .\nDort kann das entstehende Gas bei Reaktion von einer Brausetablette mit Wasser entweichen und es entsteht kein konstantes Verhältnis .\nBei B kann das Gas nicht entweichen und dadurch lässt sich das Gas nachweisen und es entstehen konstante Konzentrationverhältnisse .\n', 'rubric': {'Incorrect': ['Die Schüler:innen bewerten die Daten nicht.', 'Die Schüler:innen bewerten die Daten, ohne einen Zusammenhang zu verschiedenen Systemen herzustellen.'], 'Correct': 'Die Schüler:innen bewerten die Daten im Zusammenhang verschiedener Systeme.'}, 'score': 'Correct', 'amati': {'literals': [{'pred': 'contains', 'document': 'student_response', 'lemma': '"gas"', 'id': '@1'}], 'prediction': 'correct'}}
# Current: 1/3086
# Current: 2/3086
# Current: 3/3086
# Current: 4/3086
# Current: 5/3086
# Current: 6/3086
# Current: 7/3086
# Current: 8/3086
# Current: 9/3086
# Current: 10/3086
# Current: 11/3086
# Current: 12/3086
# Current: 13/3086
# Current: 14/3086
# Current: 15/3086
# Current: 16/3086
# Current: 17/3086
# Current: 18/3086
# Current: 19/3086
# Current: 20/3086
# Current: 21/3086
# Current: 22/3086
# Current: 23/3086
# Current: 24/3086
# Current: 25/3086
# Current: 26/3086
# Current: 27/3086
# Current: 28/3086
# Current: 29/3086
# Current: 30/3086
# Current: 31/3086
# Current: 32/3086
# Current: 33/3086
# Current: 34/3086
# Current: 35/3086
# Current: 36/3086
# Current: 37/3086
# Current: 38/3086
# Current: 39/3086
# Current: 40/3086
# Current: 41/3086
# Current: 42/3086
# Current: 43/3086
# Current: 44/3086
# Current: 45/3086
# Current: 46/3086
# Current: 47/3086
# Current: 48/3086
# Current: 49/3086
# Current: 50/3086
# Current: 51/3086
# Current: 52/3086
# Current: 53/3086
# Current: 54/3086
# Current: 55/3086
# Current: 56/3086
# Current: 57/3086
# Current: 58/3086
# Current: 59/3086
# Current: 60/3086
# Current: 61/3086
# Current: 62/3086
# Current: 63/3086
# Current: 64/3086
# Current: 65/3086
# Current: 66/3086
# Current: 67/3086
# Current: 68/3086
# Current: 69/3086
# Current: 70/3086
# Current: 71/3086
# Current: 72/3086
# Current: 73/3086
# Current: 74/3086
# Current: 75/3086
# Current: 76/3086
# Current: 77/3086
# Current: 78/3086
# Current: 79/3086
# Current: 80/3086
# Current: 81/3086
# Current: 82/3086
# Current: 83/3086
# Current: 84/3086
# Current: 85/3086
# Current: 86/3086
# Current: 87/3086
# Current: 88/3086
# Current: 89/3086
# Current: 90/3086
# Current: 91/3086
# Current: 92/3086
# Current: 93/3086
# Current: 94/3086
# Current: 95/3086
# Current: 96/3086
# Current: 97/3086
# Current: 98/3086
# Current: 99/3086
# Current: 100/3086
# Current: 101/3086
# Current: 102/3086
# Current: 103/3086
# Current: 104/3086
# Current: 105/3086
# Current: 106/3086
# Current: 107/3086
# Current: 108/3086
# Current: 109/3086
# Current: 110/3086
# Current: 111/3086
# Current: 112/3086
# Current: 113/3086
# Current: 114/3086
# Current: 115/3086
# Current: 116/3086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 for task in tasks:
#       3     for case in cases:
# ----> 4         run_experiment(task, track, case)
#
# Cell In[6], line 77, in run_experiment(task, track, case)
#      73     print(f"Current: {count}/{len(input_data)}")
#      74     # full_current_prompt_tokenized = tokenizer.encode(current_system_prompt+current_prompt)
#      75     # print(len(full_current_prompt_tokenized))
# ---> 77     response = client.chat.complete(
#      78         model="mistral-large-latest",
#      79         messages=[
#      80             {
#      81                 "role": "system",
#      82                 "content": current_system_prompt
#      83             },
#      84             {
#      85                 "role": "user",
#      86                 "content": current_prompt
#      87             }
#      88         ],
#      89         response_format={
#      90             "type": "json_schema",
#      91             "json_schema": {
#      92                 "name": "bea",
#      93                 "strict": True,
#      94                 "schema_definition": schema[task]
#      95             }
#      96         }
#      97     )
#      98     #batch_request = {
#      99     #    "custom_id": f"{case}_{count}",
#     100     #    "body": {
#    (...)    108 #    for request in batch_requests:
#     109 #        f.write(ujson.dumps(request) + "\n")
#     111     responses.append(response.choices[0].message.content)
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/mistralai/client/chat.py:248, in Chat.complete(self, model, messages, temperature, top_p, max_tokens, stream, stop, random_seed, metadata, response_format, tools, tool_choice, presence_penalty, frequency_penalty, n, prediction, parallel_tool_calls, prompt_mode, guardrails, safe_prompt, retries, server_url, timeout_ms, http_headers)
#     245 if isinstance(retries, utils.RetryConfig):
#     246     retry_config = (retries, ["429", "500", "502", "503", "504"])
# --> 248 http_res = self.do_request(
#     249     hook_ctx=HookContext(
#     250         config=self.sdk_configuration,
#     251         base_url=base_url or "",
#     252         operation_id="chat_completion_v1_chat_completions_post",
#     253         oauth2_scopes=None,
#     254         security_source=get_security_from_env(
#     255             self.sdk_configuration.security, models.Security
#     256         ),
#     257     ),
#     258     request=req,
#     259     error_status_codes=["422", "4XX", "5XX"],
#     260     retry_config=retry_config,
#     261 )
#     263 response_data: Any = None
#     264 if utils.match_response(http_res, "200", "application/json"):
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/mistralai/client/basesdk.py:297, in BaseSDK.do_request(self, hook_ctx, request, error_status_codes, stream, retry_config)
#     295     http_res = utils.retry(do, utils.Retries(retry_config[0], retry_config[1]))
#     296 else:
# --> 297     http_res = do()
#     299 if not utils.match_status_codes(error_status_codes, http_res.status_code):
#     300     http_res = hooks.after_success(AfterSuccessContext(hook_ctx), http_res)
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/mistralai/client/basesdk.py:260, in BaseSDK.do_request.<locals>.do()
#     257     if client is None:
#     258         raise ValueError("client is required")
# --> 260     http_res = client.send(req, stream=stream)
#     261 except Exception as e:
#     262     _, e = hooks.after_error(AfterErrorContext(hook_ctx), None, e)
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Work/Projects/AI & Assessment/BEA 2026/bea-2026/.venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.11/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.11/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
print(f"{task} {case}")
# Out:
# 3-way with_theory
