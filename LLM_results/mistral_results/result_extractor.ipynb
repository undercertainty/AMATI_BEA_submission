# %%
import pandas as pd

# %%
out_df=pd.read_json('/Users/alistair.willis/repos/bea-2026/BEA_full_challenge_attempt/2-way-test/2way_hf_predictions_mistral.json').rename({'prediction':'score'}, axis='columns')[['id', 'question_id', 'score']]

out_df
# Out:
#                                         id  \
# 0     07c11daa-975c-4717-9bb7-17f803bb28b1
# 1     9822a411-e3ff-42a9-ba4b-345799fd34fa
# 2     016e748a-ea1b-4554-a1c3-d81695eae686
# 3     125f6502-f504-4e42-a74b-f0a685d80dbb
# 4     862ca562-6e05-4cfb-b1c3-b614529c3ddf
# ...                                    ...
# 2003  06699b08-b204-4276-8dd9-b66f95093b78
# 2004  30cd7996-2c24-40c9-a0fc-c2e9271bab01
# 2005  99c7fd76-e8c4-46ae-9711-a051c899d143
# 2006  a935d743-874f-4e81-845e-8373b1786612
# 2007  96ee04cb-dc50-4872-be78-6bd20d913231
#
#                                question_id      score
# 0     a400cdc0-ed2f-4adf-928d-816320717a92    Correct
# 1     a400cdc0-ed2f-4adf-928d-816320717a92  Incorrect
# 2     a400cdc0-ed2f-4adf-928d-816320717a92    Correct
# 3     a400cdc0-ed2f-4adf-928d-816320717a92  Incorrect
# 4     a400cdc0-ed2f-4adf-928d-816320717a92  Incorrect
# ...                                    ...        ...
# 2003  dddf3a9d-2f40-402c-b650-3db1b27128ca  Incorrect
# ...

# %%
set(out_df['score'])
# Out:
# {'Correct', 'Incorrect'}

# %%
out_df.to_json('/Users/alistair.willis/repos/bea-2026/BEA_full_challenge_attempt/2-way-test/submission.json', orient='records')
